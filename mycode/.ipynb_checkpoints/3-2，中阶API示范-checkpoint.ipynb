# %% [markdown]
# # 3-2，中阶API示范

# %% [markdown]
# 下面的范例使用TensorFlow的中阶API实现线性回归模型和和DNN二分类模型。
#
# TensorFlow的中阶API主要包括各种模型层，损失函数，优化器，数据管道，特征列等等。

# %%
import tensorflow as tf

#打印时间分割线
@tf.function
def printbar():
    today_ts = tf.timestamp()%(24*60*60)

    hour = tf.cast(today_ts//3600+8,tf.int32)%tf.constant(24)
    minite = tf.cast((today_ts%3600)//60,tf.int32)
    second = tf.cast(tf.floor(today_ts%60),tf.int32)
    
    def timeformat(m):
        if tf.strings.length(tf.strings.format("{}",m))==1:
            return(tf.strings.format("0{}",m))
        else:
            return(tf.strings.format("{}",m))
    
    timestring = tf.strings.join([timeformat(hour),timeformat(minite),
                timeformat(second)],separator = ":")
    tf.print("=========="*8+timestring)

# %% [markdown]
# ## 一、线性回归模型

# %% [markdown]
# ### 1，准备数据

# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt 
import tensorflow as tf
from tensorflow.keras import layers,losses,metrics,optimizers

# %%
#样本数量
n = 400

# 生成测试用数据集
X = tf.random.uniform([n,2],minval=-10,maxval=10) 
w0 = tf.constant([[2.0],[-3.0]])
b0 = tf.constant([[3.0]])
Y = X@w0 + b0 + tf.random.normal([n,1],mean = 0.0,stddev= 2.0)  # @表示矩阵乘法,增加正态扰动

# %%
# 数据可视化
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
plt.figure(figsize = (12,5))
ax1 = plt.subplot(121)
ax1.scatter(X[:,0],Y[:,0], c = "b")
plt.xlabel("x1")
plt.ylabel("y",rotation = 0)

ax2 = plt.subplot(122)
ax2.scatter(X[:,1],Y[:,0], c = "g")
plt.xlabel("x2")
plt.ylabel("y",rotation = 0)
plt.show()

# %%
#构建输入数据管道
ds = tf.data.Dataset.from_tensor_slices((X,Y)) \
     .shuffle(buffer_size = 100).batch(5) \
     .prefetch(tf.data.experimental.AUTOTUNE)

# %%
ds
# Out:
# <PrefetchDataset shapes: ((None, 2), (None, 1)), types: (tf.float32, tf.float32)>

# %%
len(ds)
# Out:
# 80

# %%
list(ds)
# Out:
# [(<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-9.07486  ,  5.604377 ],
#          [ 2.507434 ,  7.771242 ],
#          [ 0.722661 , -7.67282  ],
#          [-6.38402  ,  8.78051  ],
#          [-7.150736 , -0.6844063]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-32.65232 ],
#          [-17.881008],
#          [ 26.396824],
#          [-34.19085 ],
#          [-10.193711]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 7.6247234, -1.7136459],
#          [ 5.223689 ,  1.0774088],
#          [ 1.010766 , -6.2859344],
#          [-2.6868415, -7.6059794],
#          [ 1.6224146, -7.411847 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[20.133617],
#          [10.544722],
#          [21.18446 ],
#          [20.900705],
#          [28.255817]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-2.8681707 ,  2.3693466 ],
#          [-4.2048955 , -2.8331256 ],
#          [-5.5223274 ,  4.882633  ],
#          [ 0.05153847, -8.17327   ],
#          [-4.38982   , -2.3690128 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-10.789933 ],
#          [  3.874828 ],
#          [-23.817886 ],
#          [ 27.039833 ],
#          [  0.8646077]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-5.6263614 ,  3.2065725 ],
#          [ 9.82321   ,  9.83004   ],
#          [-3.486786  ,  4.7435904 ],
#          [ 3.670311  , -8.338806  ],
#          [-4.9333024 ,  0.66918564]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-18.142324 ],
#          [ -7.0207953],
#          [-16.021383 ],
#          [ 35.51781  ],
#          [ -5.854354 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 1.2947035 , -7.3056054 ],
#          [-6.7172956 , -0.42053986],
#          [ 8.087181  ,  3.2154827 ],
#          [-9.56847   , -7.0129275 ],
#          [-9.789093  , -3.1108665 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[27.714115 ],
#          [-6.337268 ],
#          [ 8.55739  ],
#          [ 4.1981764],
#          [-5.2968626]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 1.7028713,  1.5532017],
#          [-1.0620689, -2.6606584],
#          [-1.866746 ,  8.357695 ],
#          [-8.487766 ,  9.413692 ],
#          [-6.747453 ,  4.096012 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[  1.7797816],
#          [ 10.977177 ],
#          [-27.054062 ],
#          [-41.2554   ],
#          [-22.2006   ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-2.9684615,  3.680313 ],
#          [-8.313265 ,  5.928953 ],
#          [ 3.1656122,  4.6238537],
#          [-2.3461866,  4.457987 ],
#          [ 0.9028244, -6.9869637]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-11.498184 ],
#          [-29.633333 ],
#          [ -2.5138862],
#          [-17.786524 ],
#          [ 25.806524 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 2.8271246,  2.917552 ],
#          [ 8.327427 , -3.7380624],
#          [ 3.897996 , -4.329698 ],
#          [-2.1746802,  7.6341915],
#          [-8.694361 , -5.843377 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ -1.8074528],
#          [ 31.896282 ],
#          [ 23.3935   ],
#          [-24.149572 ],
#          [  2.7645571]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 6.818819  , -0.70779324],
#          [ 7.7225533 ,  1.7797565 ],
#          [ 1.875946  ,  1.1602259 ],
#          [ 1.6068268 , -9.639175  ],
#          [ 1.2751083 ,  9.440933  ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 18.204325],
#          [ 14.379554],
#          [  3.556978],
#          [ 38.391804],
#          [-22.277412]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-9.284825 ,  0.946393 ],
#          [ 4.6670036,  3.338275 ],
#          [ 3.3014393,  2.8569365],
#          [ 7.877369 ,  5.439968 ],
#          [ 8.30612  , -8.257692 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-14.680291 ],
#          [  4.1917405],
#          [  4.305093 ],
#          [  2.364004 ],
#          [ 44.1848   ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 6.9751015 , -6.911912  ],
#          [-5.2944183 , -6.2988997 ],
#          [ 0.93045425, -4.730432  ],
#          [-9.863289  ,  9.094746  ],
#          [-4.188676  ,  9.146803  ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 40.063877],
#          [ 13.794852],
#          [ 17.625582],
#          [-43.02017 ],
#          [-32.900356]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 5.39937  ,  9.615429 ],
#          [ 4.241951 , -4.66208  ],
#          [ 8.4601555,  3.5804482],
#          [-3.884902 ,  2.8571434],
#          [-2.4032307,  9.482508 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-13.690806],
#          [ 24.195791],
#          [  8.677413],
#          [-10.549604],
#          [-28.34921 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-8.45716  ,  6.5143356],
#          [ 0.9934616,  1.6604471],
#          [-6.840477 ,  5.293193 ],
#          [-4.791918 , -9.469622 ],
#          [-9.817972 , -3.7283802]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-33.686554],
#          [ -3.141913],
#          [-26.104893],
#          [ 21.19847 ],
#          [ -4.952502]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 0.8354454, -9.338384 ],
#          [ 3.222046 ,  9.386044 ],
#          [-5.5218005,  9.89481  ],
#          [ 2.5317497, -4.688511 ],
#          [-5.9766316, -7.191124 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 31.524158],
#          [-16.039524],
#          [-37.152058],
#          [ 22.923851],
#          [  8.847546]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-7.5356174,  5.3776283],
#          [ 7.485731 ,  5.117447 ],
#          [-1.6197729, -6.7451644],
#          [-3.9160466,  2.6529646],
#          [ 5.1713295,  8.501112 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-28.78432  ],
#          [  6.1091423],
#          [ 19.282139 ],
#          [-10.375817 ],
#          [-12.193398 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 7.3065224, -4.4829774],
#          [ 0.710804 , -3.561542 ],
#          [ 4.4105225,  3.6577225],
#          [-6.323428 , -1.7919064],
#          [ 4.24664  ,  3.277275 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[31.537144 ],
#          [20.045832 ],
#          [-0.9605173],
#          [-4.3795605],
#          [ 6.6464033]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-8.574608 , -5.04838  ],
#          [-9.266146 ,  8.505924 ],
#          [ 6.941242 ,  1.5566826],
#          [-4.3429327, -8.351967 ],
#          [ 0.576107 , -2.4712706]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[  2.4668221],
#          [-40.36071  ],
#          [ 17.126675 ],
#          [ 20.859737 ],
#          [ 13.376304 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-0.21855831,  5.610712  ],
#          [ 3.8306713 , -5.9072137 ],
#          [-2.1433353 , -8.397465  ],
#          [-1.352623  ,  1.1144333 ],
#          [ 4.3590755 , -0.79499054]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-15.373594  ],
#          [ 26.003101  ],
#          [ 25.060648  ],
#          [ -0.37967992],
#          [ 15.230683  ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-5.7741833 ,  0.35500717],
#          [ 4.303422  , -5.1667833 ],
#          [-8.045265  ,  7.432953  ],
#          [ 5.4454403 ,  9.078472  ],
#          [ 9.270065  ,  0.03893661]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ -5.8249173],
#          [ 25.673641 ],
#          [-36.968784 ],
#          [-15.248761 ],
#          [ 24.462463 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 7.974386 , -9.157996 ],
#          [ 6.5603333,  5.4528255],
#          [-1.3525753, -2.657628 ],
#          [ 7.510374 ,  7.9382534],
#          [-8.375776 , -2.5760984]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[46.71677  ],
#          [ 1.5282996],
#          [ 8.632597 ],
#          [-7.3862314],
#          [-7.2668004]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-3.3534098, -1.8719406],
#          [ 4.9966927, -3.6334157],
#          [-9.309278 ,  7.537859 ],
#          [ 5.822611 ,  1.1955185],
#          [-1.5230389,  9.946625 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ -2.197548],
#          [ 26.22798 ],
#          [-38.48961 ],
#          [ 10.46886 ],
#          [-32.399803]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 6.9114151e+00,  2.3692036e+00],
#          [-9.8844795e+00,  8.8644028e-03],
#          [-3.8884163e-01, -4.4843006e+00],
#          [ 5.2639599e+00, -6.8863869e+00],
#          [-5.5838275e+00, -6.6717839e+00]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 11.193728],
#          [-16.66059 ],
#          [ 12.538226],
#          [ 31.816936],
#          [ 14.878732]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 4.133668 ,  1.5780115],
#          [-6.6175103, -9.714077 ],
#          [ 8.828194 ,  2.7907734],
#          [-5.9518147, -9.630308 ],
#          [ 3.195448 , -4.2181325]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 8.466214],
#          [16.540531],
#          [15.755272],
#          [20.671942],
#          [23.262506]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 2.0097332, -6.8418384],
#          [-1.8618107,  7.909853 ],
#          [ 7.3991623, -4.8819733],
#          [-7.5174284, -7.947438 ],
#          [-3.0037212, -5.6957197]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 26.985374 ],
#          [-23.785572 ],
#          [ 29.371752 ],
#          [ 15.221912 ],
#          [ 14.0062475]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-1.5993547, -4.234402 ],
#          [ 7.4088516, -1.6974735],
#          [-6.393428 , -5.392325 ],
#          [ 8.591692 , -7.919979 ],
#          [ 1.6653824,  5.402169 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 12.894377],
#          [ 21.219284],
#          [  7.727176],
#          [ 45.12421 ],
#          [-12.486669]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 1.3699169,  3.6182308],
#          [-8.11347  ,  8.922184 ],
#          [-7.3933697, -1.6626434],
#          [ 2.681737 ,  7.2293453],
#          [ 5.9726334,  9.0839   ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ -3.3286552],
#          [-42.478886 ],
#          [ -5.4110894],
#          [-11.508938 ],
#          [-12.1874275]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-2.3684025,  5.095315 ],
#          [ 4.8550873,  7.7580986],
#          [ 8.5818   ,  2.7699947],
#          [ 7.624645 ,  8.490303 ],
#          [-8.884721 ,  3.1707   ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-15.487894],
#          [-13.672028],
#          [ 14.288006],
#          [ -7.648952],
#          [-23.70812 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 1.8207073 , -6.454234  ],
#          [-3.372848  , -9.579857  ],
#          [ 6.1110973 , -4.3657994 ],
#          [-0.88269234, -6.153846  ],
#          [-9.795525  , -4.679003  ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[25.2978   ],
#          [26.480368 ],
#          [26.679403 ],
#          [19.887665 ],
#          [-1.8623116]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-9.146374  ,  4.3524055 ],
#          [-3.3837295 , -6.196544  ],
#          [-0.8126688 ,  1.6529989 ],
#          [ 3.2968235 , -0.10903358],
#          [-7.8855395 ,  7.8162155 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-29.075281 ],
#          [ 14.651793 ],
#          [ -2.9717095],
#          [  9.394452 ],
#          [-39.579456 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 4.1983433 ,  2.4686337 ],
#          [ 4.9894695 , -1.2798595 ],
#          [ 8.708532  , -9.389057  ],
#          [-2.3681474 , -2.043717  ],
#          [-7.5211453 , -0.79972744]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[  0.9246681],
#          [ 19.029198 ],
#          [ 47.49312  ],
#          [  4.465765 ],
#          [-12.233866 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 0.5969162, -2.335887 ],
#          [ 0.9496479,  3.139351 ],
#          [ 6.762844 , -0.5329876],
#          [ 0.789628 ,  0.7735615],
#          [-4.454999 , -1.7156076]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[11.9730835],
#          [-3.2648695],
#          [20.213184 ],
#          [-1.110316 ],
#          [-0.8096268]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 1.1050892,  3.5023785],
#          [ 1.8669844, -5.0780177],
#          [-1.6254921, -1.4301109],
#          [ 9.894686 ,  6.200161 ],
#          [-4.4383883, -6.2585545]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-5.6086736],
#          [21.602657 ],
#          [ 5.0224257],
#          [ 5.289078 ],
#          [10.257168 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 7.1676254, -5.2993894],
#          [ 5.409317 , -1.4880257],
#          [-1.5671272, -1.1941738],
#          [ 8.949831 , -2.9385352],
#          [ 3.742137 ,  6.5221786]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 30.249784 ],
#          [ 18.674395 ],
#          [  7.6317754],
#          [ 29.37789  ],
#          [-10.898393 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-1.8584013, -4.2233896],
#          [-6.513233 , -9.553873 ],
#          [-9.900179 , -5.6798506],
#          [ 3.2163029,  6.767023 ],
#          [ 3.9807148,  8.591307 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 12.991332],
#          [ 18.905159],
#          [ -4.262974],
#          [-12.309584],
#          [-18.26186 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 4.7161884 , -0.9964676 ],
#          [ 0.46926308,  3.282444  ],
#          [ 8.159063  ,  5.5488205 ],
#          [ 8.878685  , -2.318778  ],
#          [-0.552618  ,  9.508055  ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 17.585083 ],
#          [ -5.3180094],
#          [  3.6206458],
#          [ 26.127289 ],
#          [-25.977398 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-9.8673725 ,  0.06496429],
#          [-1.0075073 , -7.7930784 ],
#          [-0.27338982, -5.3951    ],
#          [ 5.3729744 , -9.311047  ],
#          [ 3.1501675 , -1.7073822 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-13.476475],
#          [ 25.197039],
#          [ 16.422554],
#          [ 41.193462],
#          [ 11.431395]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-5.7905865 ,  4.958832  ],
#          [-8.234503  ,  2.825451  ],
#          [-0.06144714,  3.7489939 ],
#          [-7.257688  ,  6.800453  ],
#          [ 6.123255  , -4.0906596 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-24.184158],
#          [-22.157604],
#          [-10.547262],
#          [-28.455475],
#          [ 29.165365]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 2.5679111, -7.859504 ],
#          [-3.94233  ,  8.469017 ],
#          [-0.6506014,  7.9339943],
#          [-2.2921968, -2.573433 ],
#          [-3.549614 ,  7.831459 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 29.398554 ],
#          [-23.303185 ],
#          [-21.874262 ],
#          [  5.7877526],
#          [-32.489815 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 4.8835964 , -5.4346585 ],
#          [-0.17689514,  3.5837193 ],
#          [ 6.5413876 , -9.926085  ],
#          [-9.338002  ,  4.4372673 ],
#          [ 0.05780411,  8.086348  ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 28.322126],
#          [ -9.290941],
#          [ 48.89534 ],
#          [-27.501524],
#          [-22.45134 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-2.7664828 , -5.941415  ],
#          [-6.9955516 , -8.753937  ],
#          [-7.0560145 ,  0.90748024],
#          [-8.814797  ,  5.4242687 ],
#          [ 2.6203995 ,  9.155895  ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 19.378178],
#          [ 12.314733],
#          [-16.825623],
#          [-29.932892],
#          [-18.949697]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-2.2960973 ,  0.9785414 ],
#          [ 6.412134  ,  5.725727  ],
#          [-7.4790382 , -0.95868874],
#          [ 5.3986692 , -4.213462  ],
#          [ 1.9124794 ,  1.1701059 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-5.7703094],
#          [-2.1449728],
#          [-7.280451 ],
#          [27.399748 ],
#          [ 6.373824 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-7.62779  , -9.534672 ],
#          [-2.30448  , -2.4580693],
#          [ 5.907631 ,  5.834341 ],
#          [-5.3868294, -5.498767 ],
#          [ 2.4499512,  6.7613525]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 17.938238 ],
#          [  5.716098 ],
#          [ -2.2802913],
#          [  5.2725816],
#          [-10.169272 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-6.2492323 , -4.9069405 ],
#          [-6.070564  , -6.541276  ],
#          [ 0.18168926,  1.4110327 ],
#          [ 1.3442135 , -3.6602807 ],
#          [ 0.07243156,  0.8879013 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 2.5929136],
#          [10.218036 ],
#          [ 3.3483138],
#          [10.587433 ],
#          [ 2.5918264]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 9.536999 , -5.8479095],
#          [-9.602224 ,  7.9198914],
#          [ 3.1809902, -3.8553476],
#          [-5.0666785, -3.3396912],
#          [ 6.3182735,  4.798193 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 41.26274  ],
#          [-40.595238 ],
#          [ 20.208208 ],
#          [  0.4126432],
#          [  1.5803999]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 8.016834  , -0.6182308 ],
#          [-8.740547  , -0.60884   ],
#          [-3.5440636 ,  8.146873  ],
#          [-8.490067  ,  9.705032  ],
#          [ 0.11831474,  4.713049  ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 21.009365],
#          [-12.060955],
#          [-27.709951],
#          [-41.76615 ],
#          [-14.748034]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 1.8099928 ,  2.0694828 ],
#          [-6.317506  ,  2.159111  ],
#          [ 0.27817917,  9.466038  ],
#          [-7.028382  ,  2.206871  ],
#          [-4.315431  ,  9.494793  ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[  2.3568897],
#          [-16.431696 ],
#          [-20.907156 ],
#          [-22.303349 ],
#          [-37.555866 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 7.5573997 , -8.727579  ],
#          [-7.2018337 , -8.182556  ],
#          [-8.942091  ,  0.64053535],
#          [-8.357679  , -7.690809  ],
#          [ 2.9642506 , -0.46933937]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 44.523342 ],
#          [ 12.519723 ],
#          [-14.3705635],
#          [  8.414317 ],
#          [ 10.016604 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 8.710739 , -2.1806407],
#          [ 8.891956 , -0.9144497],
#          [-7.1172094, -9.916239 ],
#          [ 7.3933754, -7.2496057],
#          [ 8.816433 , -4.585974 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[29.657732],
#          [22.361954],
#          [20.95411 ],
#          [39.832348],
#          [33.815483]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-0.3661728, -1.8585854],
#          [-1.2517786, -7.886431 ],
#          [ 3.6814709, -7.602303 ],
#          [-2.2859144, -7.890165 ],
#          [-2.9604316, -7.8773785]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 9.400313],
#          [24.055233],
#          [32.12303 ],
#          [24.223967],
#          [21.844559]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-1.6862822 , -3.8347745 ],
#          [ 3.364935  ,  8.963335  ],
#          [-4.724419  , -0.90575695],
#          [-5.022826  ,  7.6105576 ],
#          [ 5.5624943 , -2.8514242 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 12.528789 ],
#          [-18.381258 ],
#          [ -3.6668303],
#          [-28.286629 ],
#          [ 26.345472 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 0.13469887,  1.8370552 ],
#          [ 1.2190933 , -1.0503292 ],
#          [ 6.5206146 , -9.261398  ],
#          [-7.4664474 , -5.4233217 ],
#          [-7.248373  , -1.8093395 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-1.7634795],
#          [ 8.816999 ],
#          [45.21941  ],
#          [ 2.3277054],
#          [-6.7115707]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-5.0993752, -4.572592 ],
#          [ 7.835884 , -8.810587 ],
#          [ 8.790966 ,  6.633278 ],
#          [-4.0058684, -3.3283877],
#          [-9.700691 , -6.795056 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 9.41303  ],
#          [46.225674 ],
#          [ 2.8261135],
#          [ 8.968718 ],
#          [ 5.734698 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-9.236054 , -5.647638 ],
#          [ 7.56546  , -2.840097 ],
#          [ 7.3817177, -7.132175 ],
#          [-5.7906365,  6.2159157],
#          [ 7.866972 ,  3.5353565]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[  2.0355692],
#          [ 27.43187  ],
#          [ 40.10113  ],
#          [-26.642471 ],
#          [  7.6289244]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-1.3998985 ,  2.0110273 ],
#          [ 4.319577  ,  7.9539967 ],
#          [-1.8091059 , -0.38290024],
#          [ 2.2809267 ,  9.307312  ],
#          [-2.8334546 , -2.4316359 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ -5.101409 ],
#          [-10.828365 ],
#          [ -0.4991696],
#          [-21.884264 ],
#          [  8.274551 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-5.774131 ,  9.185913 ],
#          [ 1.4148121,  8.772873 ],
#          [-8.461051 ,  8.390106 ],
#          [-9.461185 , -3.0112839],
#          [-9.408472 ,  8.303398 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-36.470203],
#          [-22.836283],
#          [-38.8866  ],
#          [ -4.565282],
#          [-41.77954 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 7.145294  ,  7.95105   ],
#          [ 7.9061813 , -4.7026777 ],
#          [ 2.9549885 , -5.7689047 ],
#          [-9.679689  ,  0.29710293],
#          [ 0.26542854,  1.4638758 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ -7.9225655],
#          [ 35.97665  ],
#          [ 27.158293 ],
#          [-19.275473 ],
#          [ -0.9784791]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 7.8078823, -9.72343  ],
#          [ 8.149853 , -8.222868 ],
#          [-6.9455314, -2.6054811],
#          [-5.6487536,  1.1300297],
#          [-6.901958 , -2.674179 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[48.718445 ],
#          [44.844116 ],
#          [-2.9611092],
#          [-9.808179 ],
#          [-3.9596004]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-5.004673  , -3.790462  ],
#          [ 1.2262774 , -4.7414446 ],
#          [ 5.0592804 ,  7.915329  ],
#          [-0.6654644 , -0.91551304],
#          [ 0.4451294 , -6.186986  ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[  4.379016],
#          [ 17.253311],
#          [-12.653308],
#          [  2.779315],
#          [ 20.679262]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-6.2576222 ,  1.5231209 ],
#          [-0.16187477,  0.05506992],
#          [-0.84604454, -8.60743   ],
#          [ 5.350439  , -1.6077156 ],
#          [ 8.526915  , -1.4743996 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-13.620909 ],
#          [  1.7662973],
#          [ 31.146997 ],
#          [ 19.328522 ],
#          [ 26.788284 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 5.053404  , -5.1182055 ],
#          [ 2.9743595 , -2.7176642 ],
#          [-2.5697017 ,  0.21382141],
#          [ 9.051294  , -5.520947  ],
#          [ 7.04047   , -6.839187  ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[30.879623 ],
#          [15.541872 ],
#          [ 0.2966571],
#          [38.750767 ],
#          [39.411827 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-2.7445674, -6.204033 ],
#          [ 8.178101 ,  8.931042 ],
#          [-6.430018 , -7.5155854],
#          [-4.6830583, -7.754743 ],
#          [-5.997157 , -2.7539992]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[19.67154  ],
#          [-5.1492767],
#          [12.559659 ],
#          [16.040194 ],
#          [-4.395795 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 5.4248123, -1.7819738],
#          [ 5.362692 , -7.4743867],
#          [-7.571044 , -5.188308 ],
#          [ 6.107485 , -4.825647 ],
#          [-9.360652 ,  4.503889 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 18.520731],
#          [ 37.307064],
#          [  7.886602],
#          [ 31.130156],
#          [-31.175379]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-6.1307383,  9.512842 ],
#          [ 8.690735 ,  5.6212597],
#          [ 2.66078  ,  5.132349 ],
#          [-5.549588 ,  6.072613 ],
#          [-6.508503 ,  0.6842308]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-37.846405],
#          [  7.294194],
#          [ -4.819166],
#          [-28.681377],
#          [-12.692914]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 5.896888 , -3.8231015],
#          [ 3.0856686, -6.6458416],
#          [ 8.814842 , -3.716066 ],
#          [ 0.8163147,  3.017373 ],
#          [ 1.286066 ,  7.6891727]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 23.94215  ],
#          [ 31.180391 ],
#          [ 30.423895 ],
#          [ -3.9980853],
#          [-22.196423 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-4.57242   ,  5.155899  ],
#          [ 3.8842678 , -9.308815  ],
#          [-5.6976748 ,  0.05030823],
#          [-9.133601  , -1.8550014 ],
#          [-6.4803433 , -9.1346245 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-22.788755 ],
#          [ 42.17558  ],
#          [ -7.1473813],
#          [-11.83403  ],
#          [ 19.5811   ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-0.35096645,  1.4343758 ],
#          [ 7.198124  ,  0.03957748],
#          [ 9.979172  , -3.1868577 ],
#          [ 7.102867  ,  9.489222  ],
#          [ 7.0946426 ,  6.851366  ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ -1.2814829],
#          [ 17.033554 ],
#          [ 30.16922  ],
#          [-10.125637 ],
#          [ -6.361224 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-6.7118645,  7.0202217],
#          [-2.4543762, -1.6865492],
#          [-3.6779141,  5.796323 ],
#          [-3.5349917, -1.9916439],
#          [ 7.533636 ,  1.8785095]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-30.035471 ],
#          [  3.9445825],
#          [-20.246782 ],
#          [  2.491259 ],
#          [ 13.755883 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-8.037772  ,  0.18618107],
#          [-2.018919  ,  1.9737005 ],
#          [ 7.0081043 , -1.2431831 ],
#          [ 6.2252655 , -5.3785014 ],
#          [ 6.6831474 ,  3.727579  ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-15.807257 ],
#          [ -6.116297 ],
#          [ 15.86677  ],
#          [ 28.705597 ],
#          [  5.1846213]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 0.6802826 , -2.526679  ],
#          [ 9.760872  , -5.1453805 ],
#          [ 6.9862595 ,  7.969143  ],
#          [-6.6823435 , -2.3194313 ],
#          [ 4.3006372 , -0.22479534]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[11.670629 ],
#          [37.977512 ],
#          [-5.2593746],
#          [-5.1531177],
#          [11.58831  ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-6.6068053,  7.8178806],
#          [ 3.8576984,  1.3631268],
#          [ 0.4235859, -2.6038814],
#          [ 3.0979996, -2.355466 ],
#          [-4.465339 , -5.8821487]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-34.473316 ],
#          [  5.943611 ],
#          [ 10.7748165],
#          [ 17.248215 ],
#          [ 13.248844 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-6.105609 ,  8.542942 ],
#          [-6.320133 , -4.4467998],
#          [-1.31316  ,  9.391373 ],
#          [-9.841657 ,  7.289505 ],
#          [-2.0345879,  1.9110947]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-35.61518  ],
#          [  2.7396905],
#          [-26.431952 ],
#          [-34.76547  ],
#          [ -9.124727 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-7.507286 , -3.520608 ],
#          [ 7.6158104,  9.327108 ],
#          [ 3.642046 , -9.634552 ],
#          [ 5.1236134, -0.804842 ],
#          [ 7.58375  , -2.0171309]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ -2.546948],
#          [-10.267667],
#          [ 38.98274 ],
#          [ 15.359611],
#          [ 26.96716 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 0.06471157, -2.7352715 ],
#          [ 2.3934937 ,  8.087797  ],
#          [-5.3561974 ,  8.789505  ],
#          [-3.2251716 ,  6.9286747 ],
#          [ 7.588688  , -4.662423  ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 12.4470625],
#          [-14.1824875],
#          [-34.722507 ],
#          [-26.146292 ],
#          [ 29.311466 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-3.309009 , -6.898792 ],
#          [ 4.405608 , -7.141919 ],
#          [ 3.1744938, -1.1522865],
#          [-6.373353 , -3.646922 ],
#          [-6.3973618,  4.111994 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 18.35245  ],
#          [ 31.491623 ],
#          [ 10.854202 ],
#          [  1.6317943],
#          [-25.046051 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 8.067085  , -2.1458936 ],
#          [ 3.8585835 , -3.9291358 ],
#          [ 0.76372147, -1.3215523 ],
#          [ 7.2246437 , -2.860732  ],
#          [-3.80486   ,  0.5426235 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[24.915403 ],
#          [23.0448   ],
#          [ 7.582409 ],
#          [29.428205 ],
#          [-6.5201445]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-2.4104786, -4.635167 ],
#          [ 8.585915 , -2.7432227],
#          [ 1.8217373, -0.9885502],
#          [ 7.0505104,  7.258322 ],
#          [ 5.6462936,  1.5370035]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[11.87663 ],
#          [26.780281],
#          [ 7.457757],
#          [-5.147791],
#          [10.489177]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 3.6573172 ,  0.23952675],
#          [-5.914967  , -7.268491  ],
#          [-6.338291  , -2.2311497 ],
#          [ 3.8296776 , -4.5768094 ],
#          [-5.075948  ,  5.9756584 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 10.098227],
#          [ 11.536419],
#          [ -4.403604],
#          [ 25.625683],
#          [-27.025337]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[-0.6625347 , -3.5942483 ],
#          [ 0.16313362, -6.240711  ],
#          [-5.7653165 , -2.2043777 ],
#          [ 1.982687  ,  6.068533  ],
#          [-7.3231792 ,  7.3117943 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 10.520355  ],
#          [ 26.946125  ],
#          [ -0.16711807],
#          [-10.396786  ],
#          [-34.283546  ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 8.838684  ,  9.44986   ],
#          [ 0.11883736, -3.103633  ],
#          [ 8.743137  , -3.277917  ],
#          [ 9.862898  , -9.539251  ],
#          [ 7.3381157 , -7.2475004 ]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[-7.8745747],
#          [13.706115 ],
#          [32.213467 ],
#          [51.85227  ],
#          [38.999508 ]], dtype=float32)>),
#  (<tf.Tensor: shape=(5, 2), dtype=float32, numpy=
#   array([[ 2.879963 , -4.8639464],
#          [-2.8541684, -6.4932632],
#          [-4.7948647,  5.9654636],
#          [ 5.501049 ,  3.724866 ],
#          [ 4.7139378,  3.6862755]], dtype=float32)>,
#   <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#   array([[ 24.857279  ],
#          [ 18.686876  ],
#          [-26.675562  ],
#          [  0.18064547],
#          [  2.979539  ]], dtype=float32)>)]

# %% [markdown]
# ### 2，定义模型

# %%
model = layers.Dense(units = 1) 
model.build(input_shape = (2,)) #用build方法创建variables
model.loss_func = losses.mean_squared_error
model.optimizer = optimizers.SGD(learning_rate=0.001)

# %% [markdown]
# ### 3,训练模型

# %%
#使用autograph机制转换成静态图加速

@tf.function
def train_step(model, features, labels):
    with tf.GradientTape() as tape:
        predictions = model(features)
        loss = model.loss_func(tf.reshape(labels,[-1]), tf.reshape(predictions,[-1]))
    grads = tape.gradient(loss,model.variables)
    model.optimizer.apply_gradients(zip(grads,model.variables))
    return loss

# 测试train_step效果
features,labels = next(ds.as_numpy_iterator())
train_step(model,features,labels)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=195.17982>

# %%
def train_model(model,epochs):
    for epoch in tf.range(1,epochs+1):
        loss = tf.constant(0.0)
        for features, labels in ds:
            loss = train_step(model,features,labels)
        if epoch%50==0:
            printbar()
            tf.print("epoch =",epoch,"loss = ",loss)
            tf.print("w =",model.variables[0])
            tf.print("b =",model.variables[1])
train_model(model,epochs = 200)
# Out:
# ================================================================================14:52:14
# epoch = 50 loss =  6.63653278
# w = [[2.00572443]
#  [-3.03004742]]
# b = [3.14929247]
# ================================================================================14:52:15
# epoch = 100 loss =  7.29410028
# w = [[2.01923728]
#  [-3.04735661]]
# b = [3.15587044]
# ================================================================================14:52:16
# epoch = 150 loss =  2.2957828
# w = [[2.01859331]
#  [-3.0770812]]
# b = [3.15582538]
# ================================================================================14:52:18
# epoch = 200 loss =  3.70962334
# w = [[1.99729133]
#  [-3.04156804]]
# b = [3.1461]

# %%
# 结果可视化

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

w,b = model.variables

plt.figure(figsize = (12,5))
ax1 = plt.subplot(121)
ax1.scatter(X[:,0],Y[:,0], c = "b",label = "samples")
ax1.plot(X[:,0],w[0]*X[:,0]+b[0],"-r",linewidth = 5.0,label = "model")
ax1.legend()
plt.xlabel("x1")
plt.ylabel("y",rotation = 0)



ax2 = plt.subplot(122)
ax2.scatter(X[:,1],Y[:,0], c = "g",label = "samples")
ax2.plot(X[:,1],w[1]*X[:,1]+b[0],"-r",linewidth = 5.0,label = "model")
ax2.legend()
plt.xlabel("x2")
plt.ylabel("y",rotation = 0)

plt.show()

# %% [markdown]
# ## 二、DNN二分类模型

# %% [markdown]
# ### 1，准备数据

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
import tensorflow as tf
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
#正负样本数量
n_positive,n_negative = 2000,2000

#生成正样本, 小圆环分布
r_p = 5.0 + tf.random.truncated_normal([n_positive,1],0.0,1.0)
theta_p = tf.random.uniform([n_positive,1],0.0,2*np.pi) 
Xp = tf.concat([r_p*tf.cos(theta_p),r_p*tf.sin(theta_p)],axis = 1)
Yp = tf.ones_like(r_p)

#生成负样本, 大圆环分布
r_n = 8.0 + tf.random.truncated_normal([n_negative,1],0.0,1.0)
theta_n = tf.random.uniform([n_negative,1],0.0,2*np.pi) 
Xn = tf.concat([r_n*tf.cos(theta_n),r_n*tf.sin(theta_n)],axis = 1)
Yn = tf.zeros_like(r_n)

#汇总样本
X = tf.concat([Xp,Xn],axis = 0)
Y = tf.concat([Yp,Yn],axis = 0)


#可视化
plt.figure(figsize = (6,6))
plt.scatter(Xp[:,0].numpy(),Xp[:,1].numpy(),c = "r")
plt.scatter(Xn[:,0].numpy(),Xn[:,1].numpy(),c = "g")
plt.legend(["positive","negative"]);

# %%
#构建输入数据管道
ds = tf.data.Dataset.from_tensor_slices((X,Y)) \
     .shuffle(buffer_size = 4000).batch(100) \
     .prefetch(tf.data.experimental.AUTOTUNE)

# %%
ds
# Out:
# <PrefetchDataset shapes: ((None, 2), (None, 1)), types: (tf.float32, tf.float32)>

# %%
len(ds)
# Out:
# 40

# %% [markdown]
# ### 2，定义模型

# %%
class DNNModel(tf.Module):
    def __init__(self,name = None):
        super(DNNModel, self).__init__(name=name)
        self.dense1 = layers.Dense(4,activation = "relu") 
        self.dense2 = layers.Dense(8,activation = "relu")
        self.dense3 = layers.Dense(1,activation = "sigmoid")

     
    # 正向传播
    @tf.function(input_signature=[tf.TensorSpec(shape = [None,2], dtype = tf.float32)])  
    def __call__(self,x):
        x = self.dense1(x)
        x = self.dense2(x)
        y = self.dense3(x)
        return y
    
model = DNNModel()
model.loss_func = losses.binary_crossentropy
model.metric_func = metrics.binary_accuracy
model.optimizer = optimizers.Adam(learning_rate=0.001)

# %% [markdown]
# ### 3，训练模型
